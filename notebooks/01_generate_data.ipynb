# %%
import sys
from pathlib import Path

ROOT = Path("..").resolve()
SRC = ROOT / "src"
sys.path.insert(0, str(SRC))

print("ROOT:", ROOT)
print("SRC:", SRC)
# Out:
# ROOT: C:\Users\GLORIA MARENA\projects\context-engine-crewai
# SRC: C:\Users\GLORIA MARENA\projects\context-engine-crewai\src

# %%
from data_simulator import SimConfig, generate_items, generate_search_events, save_artifacts

cfg = SimConfig(n_items=100_000, n_sellers=5_000, n_events=10_000, seed=42)
items = generate_items(cfg)
events = generate_search_events(cfg, items)

items.head()
# Out:
#     item_id                                   title seller_id    price  \
# 0  I0000000      Lenovo Katana Laptop i5 8GB 2048GB    S00767  5190.91
# 1  I0000001                        LG UHD TV 50" 8k    S02787  4726.55
# 2  I0000002  Bose QuietComfort Headphones Bluetooth    S00355  1026.89
# 3  I0000003           Google Galaxy Phone 256GB 6GB    S01866  3250.90
# 4  I0000004  Sony QuietComfort Headphones Bluetooth    S02910  2500.00
#
#    available_quantity  sold_quantity  \
# 0                  18              3
# 1                  16             16
# 2                  13             12
# 3                  16             11
# 4                  11              1
#
#                                               tags  \
# 0                             [ram, student, work]
# 1                     [4k, smart, hdr, 55pulgadas]
# 2  [bluetooth, deporte, cancelacion_ruido, oferta]
# 3                  [5g, camara_pro, bateria_larga]
# 4                     [deporte, cancelacion_ruido]
#
#                                           attributes
# 0  {'category': 'laptop', 'brand': 'Lenovo', 'mod...
# 1  {'category': 'tv', 'brand': 'LG', 'model': 'UH...
# 2  {'category': 'headphones', 'brand': 'Bose', 'm...
# 3  {'category': 'phone', 'brand': 'Google', 'mode...
# 4  {'category': 'headphones', 'brand': 'Sony', 'm...

# %%
(ROOT / "artifacts").mkdir(exist_ok=True)
save_artifacts(items, events, out_dir=str(ROOT / "artifacts"))
print("Saved artifacts!")
# Out:
# Saved artifacts!
